# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-basic-libriaries" data-toc-modified-id="Load-basic-libriaries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load basic libriaries</a></span></li><li><span><a href="#Data-pre-processing" data-toc-modified-id="Data-pre-processing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data pre-processing</a></span><ul class="toc-item"><li><span><a href="#First-look-about-diamond-dataset" data-toc-modified-id="First-look-about-diamond-dataset-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>First look about diamond dataset</a></span></li><li><span><a href="#Drop-an-unnecessary-column-called-&quot;Unnamed&quot;" data-toc-modified-id="Drop-an-unnecessary-column-called-&quot;Unnamed&quot;-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Drop an unnecessary column called "Unnamed"</a></span></li><li><span><a href="#Remove-missing-values." data-toc-modified-id="Remove-missing-values.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Remove missing values.</a></span></li><li><span><a href="#Correlation-heatmap" data-toc-modified-id="Correlation-heatmap-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Correlation heatmap</a></span></li><li><span><a href="#Pairplot-of-Price-vs.-4-Cs-(Carat,-Cut,-Color,-Clarity)" data-toc-modified-id="Pairplot-of-Price-vs.-4-Cs-(Carat,-Cut,-Color,-Clarity)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Pairplot of Price vs. 4 Cs (Carat, Cut, Color, Clarity)</a></span></li><li><span><a href="#Distribution-of-each-feature" data-toc-modified-id="Distribution-of-each-feature-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Distribution of each feature</a></span></li><li><span><a href="#Remove-outliers" data-toc-modified-id="Remove-outliers-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Remove outliers</a></span></li><li><span><a href="#Convert-categorical-label" data-toc-modified-id="Convert-categorical-label-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Convert categorical label</a></span></li><li><span><a href="#Scaling" data-toc-modified-id="Scaling-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Scaling</a></span></li></ul></li><li><span><a href="#Model-training" data-toc-modified-id="Model-training-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Model training</a></span><ul class="toc-item"><li><span><a href="#Linear-regression" data-toc-modified-id="Linear-regression-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Linear regression</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#Neural-Networks" data-toc-modified-id="Neural-Networks-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Neural Networks</a></span></li></ul></li><li><span><a href="#Dimension-reduction" data-toc-modified-id="Dimension-reduction-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Dimension reduction</a></span><ul class="toc-item"><li><span><a href="#Feature-selection" data-toc-modified-id="Feature-selection-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Feature selection</a></span></li></ul></li><li><span><a href="#System-&amp;-design" data-toc-modified-id="System-&amp;-design-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>System &amp; design</a></span></li><li><span><a href="#Sources-and-References" data-toc-modified-id="Sources-and-References-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Sources and References</a></span><ul class="toc-item"><li><span><a href="#Related-link:" data-toc-modified-id="Related-link:-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Related link:</a></span></li><li><span><a href="#Kaggle-link" data-toc-modified-id="Kaggle-link-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Kaggle link</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Load basic libriaries

# %%
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(context="notebook", palette="Spectral", style = 'darkgrid', font_scale = 1.5, color_codes=True)
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Data pre-processing

# %%
# dataset can be download from https://www.kaggle.com/shivam2503/diamonds/home
df = pd.read_csv("diamonds.csv")

# %% [markdown]
# ##  First look about diamond dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
# Unnamed: 0    53940 non-null int64
# carat         53940 non-null float64
# cut           53940 non-null object
# color         53940 non-null object
# clarity       53940 non-null object
# depth         53940 non-null float64
# table         53940 non-null float64
# price         53940 non-null int64
# x             53940 non-null float64
# y             53940 non-null float64
# z             53940 non-null float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.shape
# Out:
# (53940, 11)

# %% [markdown]
# ## Drop an unnecessary column called "Unnamed"

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ## Remove missing values.
#
# The minimum values for x,y and z here are 0 but it is not possible because according to the data description they are the length, width and depth.

# %%
print("Number of rows with x == 0: {} ".format((df.x==0).sum()))
print("Number of rows with y == 0: {} ".format((df.y==0).sum()))
print("Number of rows with z == 0: {} ".format((df.z==0).sum()))
print("Number of rows with depth == 0: {} ".format((df.depth==0).sum()))
# Out:
# Number of rows with x == 0: 8
# Number of rows with y == 0: 7
# Number of rows with z == 0: 20
# Number of rows with depth == 0: 0

# %% [markdown]
# A zero value in these rows means missing data so we can replace the zeros with nan. Another thing to notice is that the depth column doesn't have a single zero value. We know that depth is calculated using the three parameters only.

# %%
df[['x','y','z']] = df[['x','y','z']].replace(0,np.NaN)

# %%
df.isnull().sum()
# Out:
# carat       0
# cut         0
# color       0
# clarity     0
# depth       0
# table       0
# price       0
# x           8
# y           7
# z          20
# dtype: int64

# %%
print("Raw dataset shape: {}".format(df.shape))
df.dropna(inplace=True)
print("New dataset shape: {}".format(df.shape))
# Out:
# Raw dataset shape: (53940, 10)
# New dataset shape: (53920, 10)

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# ## Correlation heatmap

# %%
plt.figure(figsize=(10, 10))
# calculate the correlation matrix
corr = df.corr()
sns.heatmap(
    corr, 
    annot=True,
    square=True
)

# %% [markdown]
# **Observations**
#
# - $x$, $y$, $z$, and $cart$ have a strong relation with $price$;
# - $table$ has medium relation with $price$;
# - $depth$ does not have a significant relation with $price$;

# %% [markdown]
# ## Pairplot of Price vs. 4 Cs (Carat, Cut, Color, Clarity)
#
# A pairs plot allows us to see both distribution of single variables and relationships between two variables.
# [source link](https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166)

# %%
sns.pairplot(df, x_vars=["carat", "cut", "clarity", "color"], y_vars = ["price"])

# %% [markdown]
# ## Distribution of each feature

# %%
df.hist(figsize=(20, 20), bins=150)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000206CFAE60F0>,
# ...
#       dtype=object)

# %%
print(df.head())
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# Convert features to log scale

# %%
# col_names = df.columns.tolist()
# col_names.remove("price")
# print(col_names)

# numerical_cols = list(df.select_dtypes(include=[np.number]).columns)
# numerical_cols.remove("price")
# print(numerical_cols)

# %%
# # replace 0 values as 0.001 to do the transform
# if 0 in df.values:
#     df[numerical_cols] = df[numerical_cols] + 0.001
#     print("Filled all 0 values with 0.001. \nNow any 0 values?: {}".format(0 in df.values))
# else:
#     print("Df does not have any 0 values.")

# %% [markdown]
# ## Remove outliers

# %%
def plot_boxplot(df, features):
    """
    Plot boxplot for all features
    """    
    fig = plt.figure(figsize=(15, 15))
    for i in range(6):
        sns.boxplot(data=df[features[i]], ax=fig.add_subplot(2, 3, i+1))
        plt.ylabel("Price")
        plt.xlabel(features[i])
    plt.show()

# %%
col_names = df.columns.tolist()
col_names.remove("price")
print(col_names)

numerical_cols = list(df.select_dtypes(include=[np.number]).columns)
numerical_cols.remove("price")
print(numerical_cols)
# Out:
# ['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z']
# ['carat', 'depth', 'table', 'x', 'y', 'z']

# %%
plot_boxplot(df, numerical_cols)

# %%
from scipy import stats

def removeoutliers(df, features, z):
    """
    Reomve outliers
    """
    for var in features:
        df_new = df[np.abs(stats.zscore(df[var])) < z]
    return df_new
  
df = removeoutliers(df, numerical_cols, 3)

# %%
plot_boxplot(df, numerical_cols)

# %%
# # this log converts dataframe's features inplace
# def convert2log(df, listvars):
#     """
#     Convert features to log values
#     """
#     for var in listvars:
#         df[var] = np.log(df[var])

# def plot_distplot(df, features):
#     """
#     Plot distplot for all features
#     """    
#     fig = plt.figure(figsize=(20, 20))
#     for i in range(9):
#         sns.distplot(df[features[i]], ax=fig.add_subplot(3, 3, i+1))
#         plt.ylabel("Price")
#         plt.xlabel(features[i])
#     plt.show()

# convert2log(df, numerical_cols)
# plot_distplot(df, col_names)

# %% [markdown]
# ## Convert categorical label

# %%
# categorical label
print("Cut: {}".format(set(df["cut"])))
print("Color: {}".format(set(df["color"])))
print("Clarity: {}".format(set(df["clarity"])))
# Out:
# Cut: {'Ideal', 'Premium', 'Fair', 'Good', 'Very Good'}
# Color: {'H', 'F', 'J', 'E', 'G', 'D', 'I'}
# Clarity: {'SI1', 'VVS1', 'VS2', 'VS1', 'IF', 'SI2', 'I1', 'VVS2'}

# %%
def convert_catg(df):
    """
    convert categorical label to numerical label
    """
    encoder = preprocessing.LabelEncoder()
 
    # Find the columns of object type along with their column index
    object_cols = list(df.select_dtypes(exclude=[np.number]).columns)
    object_cols_ind = []
    for col in object_cols:
        object_cols_ind.append(df.columns.get_loc(col))
    
    # Encode the categorical columns with numbers 
    for i in object_cols_ind:
        df.iloc[:,i] = encoder.fit_transform(df.iloc[:,i])

# %%
convert_catg(df)
df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ## Scaling

# %%
X_df = df.drop(["price"],axis=1)
y_df = df.price

# scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_df)
print(X_df.shape)
display(X_df.head())
X_df = scaler.transform(X_df)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, random_state = 2,test_size=0.3)
# Out:
# (53884, 9)
#    carat  cut  color  clarity  depth  table     x     y     z
# 0   0.23    2      1        3   61.5   55.0  3.95  3.98  2.43
# 1   0.21    3      1        2   59.8   61.0  3.89  3.84  2.31
# 2   0.23    1      1        4   56.9   65.0  4.05  4.07  2.31
# 3   0.29    3      5        5   62.4   58.0  4.20  4.23  2.63
# 4   0.31    1      6        3   63.3   58.0  4.34  4.35  2.75

# %% [markdown]
# # Model training

# %% [markdown]
# ## Linear regression

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model

reg_lr = linear_model.LinearRegression()
reg_lr.fit(X_train, y_train)
y_pred = reg_lr.predict(X_test)

print("Mean absolute error: {:.2f}".format(mean_absolute_error(y_test, y_pred)))
print("Mean squared error: {:.2f}".format(mean_squared_error(y_test, y_pred)))
print("R-Squared: {:.2f}".format(r2_score(y_test,y_pred)))
# Out:
# Mean absolute error: 828.57
# Mean squared error: 1685968.90
# R-Squared: 0.89

# %%
print(y_test[:5].values)
print(np.around(y_pred[:5]))
# Out:
# [7774 2487 2229 4732 2210]
# [9238. 2908. 3402. 7181.  735.]

# %%
coeff_df = pd.DataFrame(col_names)
coeff_df.columns = ["Variable"]
coeff_df["Coeff"] = pd.Series(reg_lr.coef_)
ret = coeff_df.sort_values(by="Coeff", ascending=False)
display(ret)
print("Intercept: {:.2f}".format(reg_lr.intercept_))
# Out:
#   Variable        Coeff
# 0    carat  5785.379922
# 3  clarity   484.467229
# 7        y   448.207012
# 1      cut    53.292389
# 4    depth  -126.346545
# 5    table  -208.081449
# 2    color  -458.776244
# 8        z  -959.522038
# 6        x -1356.118690
# Intercept: 3925.02

# %%
sns.regplot(y_test, y_pred,)
plt.xlabel("Observation")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
# Residual Histogram
sns.distplot((y_test-y_pred),bins=50)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

reg_rf = RandomForestRegressor(n_estimators = 10)
reg_rf.fit(X_train,y_train.values.ravel())
y_pred = reg_rf.predict(X_test)

print("Mean absolute error: {:.2f}".format(mean_absolute_error(y_test, y_pred)))
print("Mean squared error: {:.2f}".format(mean_squared_error(y_test, y_pred)))
print("R-Squared: {:.2f}".format(r2_score(y_test,y_pred)))
# Out:
# Mean absolute error: 280.79
# Mean squared error: 305873.39
# R-Squared: 0.98

# %%
print(y_test[:5].values)
print(np.around(y_pred[:5]))
# Out:
# [7774 2487 2229 4732 2210]
# [7706. 2365. 1944. 5705. 2167.]

# %%
sns.regplot(y_test,y_pred,'b')
plt.xlabel("Observation")
plt.ylabel("Prediction")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-24cd6dbbf54f> in <module>
# ----> 1 sns.regplot(y_test,y_pred,'b')
#       2 plt.xlabel("Observation")
#       3 plt.ylabel("Prediction")
#
# NameError: name 'sns' is not defined

# %%
# Residual Histogram
sns.distplot((y_test-y_pred),bins=50)

# %%
importances = reg_rf.feature_importances_
importance_df = pd.DataFrame(col_names)
importance_df.columns = ["Variable"]
importance_df["Importances"] = pd.Series(importances)
ret = importance_df.sort_values(by="Importances", ascending=False)
display(ret)
# Out:
#   Variable  Importances
# 0    carat     0.528082
# 7        y     0.360160
# 3  clarity     0.064994
# 2    color     0.030612
# 8        z     0.005148
# 6        x     0.003996
# 4    depth     0.003111
# 5    table     0.002439
# 1      cut     0.001459

# %% [markdown]
# ## Neural Networks

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import RMSprop
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
# Out:
# Using TensorFlow backend.

# %%
# define a neural network
def Net():
    model = Sequential()
    model.add(Dense(input_dim=9, activation="relu", units=18))
    model.add(Dense(kernel_initializer="normal", activation="relu", units=12))
    model.add(Dense(kernel_initializer="normal", units=1))
    model.compile(loss="mean_squared_error", optimizer="adam")
    return model

# %%
# estimator = KerasRegressor(build_fn=Net, epochs=10, batch_size=5)
# kf = KFold(n_splits=5)
# results = cross_val_score(estimator, X_train, y_train, cv=kf)
# print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))

# %%
estimator = KerasRegressor(build_fn=Net, epochs=10, batch_size=5)
estimator.fit(X_train, y_train)
y_pred = estimator.predict(X_test)
# Out:
# Epoch 1/10
# 37718/37718 [==============================] - 4s 114us/step - loss: 31115088.9471
# Epoch 2/10
# 37718/37718 [==============================] - 4s 110us/step - loss: 30429625.4508
# Epoch 3/10
# 37718/37718 [==============================] - 4s 110us/step - loss: 29768206.2840
# Epoch 4/10
# 37718/37718 [==============================] - 4s 110us/step - loss: 29122737.2259
# Epoch 5/10
# 37718/37718 [==============================] - 4s 110us/step - loss: 28497980.5958
# Epoch 6/10
# 37718/37718 [==============================] - 4s 110us/step - loss: 27888200.0851
# Epoch 7/10
# 37718/37718 [==============================] - 4s 111us/step - loss: 27297309.8389
# Epoch 8/10
# 37718/37718 [==============================] - 4s 110us/step - loss: 26727063.8348
# Epoch 9/10
# 37718/37718 [==============================] - 4s 110us/step - loss: 26169749.5083
# Epoch 10/10
# 37718/37718 [==============================] - 4s 112us/step - loss: 25627561.1229

# %%
print("Mean absolute error: {:.2f}".format(mean_absolute_error(y_test, y_pred)))
print("Mean squared error: {:.2f}".format(mean_squared_error(y_test, y_pred)))
print("R-Squared: {:.2f}".format(r2_score(y_test,y_pred)))
# Out:
# Mean absolute error: 3090.25
# Mean squared error: 24646586.08
# R-Squared: -0.59

# %%
sns.regplot(y_test,y_pred, color="g")
plt.xlabel("Observation")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
# Residual Histogram
sns.distplot((y_test-y_pred),bins=50)

# %% [markdown]
# # Dimension reduction

# %% [markdown]
# ## Feature selection

# %%
X_df_new = df[["carat", "clarity", "color", "y"]]
y_df_new = df.price
display(X_df_new.head())
print(X_df_new.shape)

# scaling
scaler_fs = StandardScaler()
scaler_fs.fit(X_df_new)
X_df_new = scaler_fs.fit_transform(X_df_new)

# split dataset
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X_df_new, y_df_new, random_state=2, test_size=0.3)
# Out:
#    carat  clarity  color     y
# 0   0.23        3      1  3.98
# 1   0.21        2      1  3.84
# 2   0.23        4      1  4.07
# 3   0.29        5      5  4.23
# 4   0.31        3      6  4.35
# (53884, 4)

# %%
reg_rf_new = RandomForestRegressor(n_estimators=10)
reg_rf_new.fit(X_train_new, y_train_new.values.ravel())
y_pred_new = reg_rf_new.predict(X_test_new)

print("Mean absolute error: {:.2f}".format(mean_absolute_error(y_test_new, y_pred_new)))
print("Mean squared error: {:.2f}".format(mean_squared_error(y_test_new, y_pred_new)))
print("R-Squared: {:.2f}".format(r2_score(y_test_new, y_pred_new)))
# Out:
# Mean absolute error: 325.81
# Mean squared error: 381312.95
# R-Squared: 0.98

# %%
sns.regplot(y_test_new, y_pred_new)
# max_price = max(y_test.max(), y_pred.max())
# plt.xlim(0, max_price)
# plt.ylim(0, max_price)
plt.xlabel("Observation")
plt.ylabel("Prediction")
# Out:
# Text(0,0.5,'Prediction')

# %%
# Residual Histogram
sns.distplot((y_test_new - y_pred_new),bins=50)

# %% [markdown]
# # System & design

# %%
# test a new dataset
test_df = pd.read_csv("test.csv")

display(test_df.head())

test_df.drop("Unnamed: 0", axis=1, inplace=True)
test_df[["x","y","z"]] = test_df[["x","y","z"]].replace(0, np.NaN)
test_df.dropna(inplace=True)

convert_catg(test_df)
display(test_df.head())
# X_test_df = test_df.drop(["price"], axis=1)
X_test_df = scaler.transform(test_df)
# reg_rf = RandomForestRegressor(n_estimators = 10)
# reg_rf.fit(X_train, y_train.values.ravel())

y_test_pred = reg_rf.predict(X_test_df)
print("Prediction: {}".format(y_test_pred))
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table      x      y  \
# 0           1    4.0      Ideal     D      IF   65.5     59  10.74  10.54
# 1           2    2.0      Ideal     D      IF   65.5     59  10.74  10.54
# 2           3    0.5  Very Good     G     SI1   61.4     56   4.33   4.37
# 3           4    0.3       Good     E    VVS1   59.7     58   4.13   4.14
#
#       z
# 0  6.98
# 1  6.98
# 2  2.67
# 3  2.47
#    carat  cut  color  clarity  depth  table      x      y     z
# 0    4.0    1      0        0   65.5     59  10.74  10.54  6.98
# 1    2.0    1      0        0   65.5     59  10.74  10.54  6.98
# 2    0.5    2      2        1   61.4     56   4.33   4.37  2.67
# 3    0.3    0      1        2   59.7     58   4.13   4.14  2.47
# Prediction: [12148.8  9818.9  1573.8   503.2]

# %% [markdown]
# # Sources and References
#
# ## Related link:
#
# - [“Diamonds are forever” — price prediction using Machine Learning regression models and neural networks.](https://medium.com/@grover.jatin/diamonds-are-forever-price-prediction-using-machine-learning-regression-models-and-neural-f4f54b5fcf7f)
# - [Types of Regression and Stats in depth](https://www.kaggle.com/shrutimechlearn/types-of-regression-and-stats-in-depth)
#
# ## Kaggle link
#
# [Diamonds:](https://www.kaggle.com/shivam2503/diamonds)
# Analyze diamonds by their cut, color, clarity, price, and other attributes
